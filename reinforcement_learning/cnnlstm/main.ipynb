# %%
# --- Imports ---
import os
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv, VecMonitor
from env import TradingEnv
from extractor import CNNLSTMPolicy
from pathlib import Path
import pandas as pd

# --- Config ---
meta_path = Path("../dataset/meta.csv").resolve()
meta_df = pd.read_csv(meta_path, parse_dates=["timestamp"])
meta_root = meta_path.parent.resolve()

# Train/Test split
split_ratio = 0.8
split_idx = int(len(meta_df) * split_ratio)
train_df = meta_df.iloc[:split_idx].reset_index(drop=True)
test_df = meta_df.iloc[split_idx:].reset_index(drop=True)

print(f"[INFO] Training on {len(train_df)} samples, testing on {len(test_df)}")

# --- Env builders ---
def make_train_env():
    def _init():
        return TradingEnv(
            meta_df=train_df,
            root_dir=meta_root,
            n_steps=8,
            image_size=(128, 128),
            num_actions=3,
            starting_balance=100_000,
            leverage=1,
            risk_per_trade=1
        )
    return _init

def make_test_env():
    def _init():
        return TradingEnv(
            meta_df=test_df,
            root_dir=meta_root,
            n_steps=8,
            image_size=(128, 128),
            num_actions=3,
            starting_balance=100_000,
            leverage=1,
            risk_per_trade=1
        )
    return _init

# --- Env setup ---
train_env = DummyVecEnv([make_train_env()])
train_env = VecMonitor(train_env)

test_env = DummyVecEnv([make_test_env()])

# --- Model path ---
base_model_path = "ppo-cnnlstm-trading"

# --- Load or initialize model ---
if os.path.exists(base_model_path + ".zip"):
    print(f"[📂 LOADING EXISTING MODEL from {base_model_path}]")
    model = PPO.load(base_model_path, env=train_env, device="cuda")
else:
    print("[🆕 INITIALIZING NEW MODEL]")
    model = PPO(
        policy=CNNLSTMPolicy,
        env=train_env,
        verbose=1,
        n_steps=256,
        batch_size=64,
        learning_rate=1e-4,
        tensorboard_log="./logs",
        device="cuda"
    )

# --- Training loop ---
total_target_steps = 5_000_000
chunk_size = 100_000
chunks = total_target_steps // chunk_size

for i in range(chunks):
    print(f"\n[🔁 TRAINING CHUNK {i+1}/{chunks}]")
    
    model.learn(total_timesteps=chunk_size, reset_num_timesteps=False)

    steps_so_far = (i+1) * chunk_size
    chunk_model_path = f"{base_model_path}-{steps_so_far//1000}k"
    model.save(chunk_model_path)
    print(f"[✅ Saved checkpoint: {chunk_model_path}.zip]")

    # --- Test after each chunk ---
print("[🚀 TESTING STARTED]")
obs = test_env.reset()
total_rewards, episode_reward = [], 0

for _ in range(len(test_df)):
    action, _ = model.predict(obs, deterministic=True)  # << fully greedy
    obs, reward, done, info = test_env.step(action)
    episode_reward += reward[0]
    action, _ = model.predict(obs, deterministic=True)
    # print(f"Step {_}: Action={action[0]}, Info={info}")  # show chosen action + env info

    if done[0]:
        total_rewards.append(episode_reward)
        print(f"Episode reward: {episode_reward:.2f}")
        episode_reward = 0
        obs = test_env.reset()

print("\n[📊 TESTING COMPLETE]")
if total_rewards:
    print(f"Average Reward: {sum(total_rewards)/len(total_rewards):.2f}")
    print(f"Max Reward: {max(total_rewards):.2f}")
    print(f"Min Reward: {min(total_rewards):.2f}")
else:
    print("No episodes completed during testing.")
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# Users of this version of Gym should be able to simply replace 'import gym' with 'import gymnasium as gym' in the vast majority of cases.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# INFO:env:[ENV INIT] Loaded 45117 rows with 5 TFs, history=8 steps.
# INFO:env:[ENV INIT] Loaded 11280 rows with 5 TFs, history=8 steps.
# [INFO] Training on 45117 samples, testing on 11280
# [🆕 INITIALIZING NEW MODEL]
# Using cuda device
#
# [🔁 TRAINING CHUNK 1/50]
# Logging to ./logs/PPO_0
# ----------------------------
# | time/              |     |
# |    fps             | 39  |
# |    iterations      | 1   |
# |    time_elapsed    | 6   |
# |    total_timesteps | 256 |
# ----------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 20            |
# |    iterations           | 2             |
# |    time_elapsed         | 24            |
# |    total_timesteps      | 512           |
# | train/                  |               |
# |    approx_kl            | 1.9724015e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.1          |
# |    explained_variance   | 6.59e-05      |
# |    learning_rate        | 0.0001        |
# |    loss                 | 4.69e+04      |
# |    n_updates            | 10            |
# |    policy_gradient_loss | 1.24e-05      |
# |    value_loss           | 9.46e+04      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 17            |
# |    iterations           | 3             |
# |    time_elapsed         | 43            |
# |    total_timesteps      | 768           |
# | train/                  |               |
# |    approx_kl            | 0.00044840877 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.1          |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0001        |
# |    loss                 | 3.24e+04      |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -0.00113      |
# |    value_loss           | 5.79e+04      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 16           |
# |    iterations           | 4            |
# |    time_elapsed         | 62           |
# |    total_timesteps      | 1024         |
# | train/                  |              |
# |    approx_kl            | 8.120667e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | -1.43e-06    |
# |    learning_rate        | 0.0001       |
# |    loss                 | 3e+04        |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -3.53e-05    |
# |    value_loss           | 6.77e+04     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 15            |
# |    iterations           | 5             |
# |    time_elapsed         | 81            |
# |    total_timesteps      | 1280          |
# | train/                  |               |
# |    approx_kl            | 6.1357394e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.1          |
# |    explained_variance   | 2.98e-07      |
# |    learning_rate        | 0.0001        |
# |    loss                 | 3.32e+04      |
# |    n_updates            | 40            |
# |    policy_gradient_loss | -0.000191     |
# |    value_loss           | 6.46e+04      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 15           |
# |    iterations           | 6            |
# |    time_elapsed         | 100          |
# |    total_timesteps      | 1536         |
# | train/                  |              |
# |    approx_kl            | 0.0001367398 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0001       |
# |    loss                 | 4.61e+04     |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.000471    |
# |    value_loss           | 1.03e+05     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 14            |
# |    iterations           | 7             |
# |    time_elapsed         | 120           |
# |    total_timesteps      | 1792          |
# | train/                  |               |
# |    approx_kl            | 0.00020474079 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.1          |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.92e+04      |
# |    n_updates            | 60            |
# |    policy_gradient_loss | -0.000295     |
# |    value_loss           | 3.95e+04      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 14           |
# |    iterations           | 8            |
# |    time_elapsed         | 138          |
# |    total_timesteps      | 2048         |
# | train/                  |              |
# |    approx_kl            | 0.0001502966 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0001       |
# |    loss                 | 9.74e+04     |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.000631    |
# |    value_loss           | 1.98e+05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 14           |
# |    iterations           | 9            |
# |    time_elapsed         | 156          |
# |    total_timesteps      | 2304         |
# | train/                  |              |
# |    approx_kl            | 0.0004042075 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | -9.54e-07    |
# |    learning_rate        | 0.0001       |
# |    loss                 | 7.96e+04     |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00169     |
# |    value_loss           | 1.96e+05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 14           |
# |    iterations           | 10           |
# |    time_elapsed         | 174          |
# |    total_timesteps      | 2560         |
# | train/                  |              |
# |    approx_kl            | 0.0022543296 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 4.77e-07     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 2.14e+04     |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00534     |
# |    value_loss           | 4.24e+04     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 14            |
# |    iterations           | 11            |
# |    time_elapsed         | 192           |
# |    total_timesteps      | 2816          |
# | train/                  |               |
# |    approx_kl            | 0.00039953995 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.09         |
# |    explained_variance   | -5.84e-06     |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.42e+04      |
# |    n_updates            | 100           |
# |    policy_gradient_loss | -0.00043      |
# |    value_loss           | 2.55e+04      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 14            |
# |    iterations           | 12            |
# |    time_elapsed         | 210           |
# |    total_timesteps      | 3072          |
# | train/                  |               |
# |    approx_kl            | 0.00045384048 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.09         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.94e+04      |
# |    n_updates            | 110           |
# |    policy_gradient_loss | -0.00118      |
# |    value_loss           | 4.57e+04      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 14            |
# |    iterations           | 13            |
# |    time_elapsed         | 228           |
# |    total_timesteps      | 3328          |
# | train/                  |               |
# |    approx_kl            | 6.0862163e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.08         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0001        |
# |    loss                 | 4.99e+04      |
# |    n_updates            | 120           |
# |    policy_gradient_loss | -0.000155     |
# |    value_loss           | 9.62e+04      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 14           |
# |    iterations           | 14           |
# |    time_elapsed         | 246          |
# |    total_timesteps      | 3584         |
# | train/                  |              |
# |    approx_kl            | 0.0001820249 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | -4.77e-07    |
# |    learning_rate        | 0.0001       |
# |    loss                 | 3.03e+04     |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.000602    |
# |    value_loss           | 5.1e+04      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 14           |
# |    iterations           | 15           |
# |    time_elapsed         | 265          |
# |    total_timesteps      | 3840         |
# | train/                  |              |
# |    approx_kl            | 5.194987e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0001       |
# |    loss                 | 5.1e+04      |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -6.96e-05    |
# |    value_loss           | 9.98e+04     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 14            |
# |    iterations           | 16            |
# |    time_elapsed         | 284           |
# |    total_timesteps      | 4096          |
# | train/                  |               |
# |    approx_kl            | 0.00016323035 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.08         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0001        |
# |    loss                 | 3.81e+04      |
# |    n_updates            | 150           |
# |    policy_gradient_loss | -0.000655     |
# |    value_loss           | 7.64e+04      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 14            |
# |    iterations           | 17            |
# |    time_elapsed         | 303           |
# |    total_timesteps      | 4352          |
# | train/                  |               |
# |    approx_kl            | 0.00039013638 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.08         |
# |    explained_variance   | 5.96e-07      |
# |    learning_rate        | 0.0001        |
# |    loss                 | 2.52e+04      |
# |    n_updates            | 160           |
# |    policy_gradient_loss | -0.0011       |
# |    value_loss           | 6.17e+04      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 14           |
# |    iterations           | 18           |
# |    time_elapsed         | 322          |
# |    total_timesteps      | 4608         |
# | train/                  |              |
# |    approx_kl            | 0.0010658575 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.58e+04     |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00208     |
# |    value_loss           | 2.48e+04     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 14            |
# |    iterations           | 19            |
# |    time_elapsed         | 341           |
# |    total_timesteps      | 4864          |
# | train/                  |               |
# |    approx_kl            | 0.00021179044 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.09         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0001        |
# |    loss                 | 2.23e+04      |
# |    n_updates            | 180           |
# |    policy_gradient_loss | -0.000521     |
# |    value_loss           | 4.71e+04      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 14            |
# |    iterations           | 20            |
# |    time_elapsed         | 360           |
# |    total_timesteps      | 5120          |
# | train/                  |               |
# |    approx_kl            | 0.00014451216 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.09         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0001        |
# |    loss                 | 6.1e+04       |
# |    n_updates            | 190           |
# |    policy_gradient_loss | -0.000503     |
# |    value_loss           | 1.31e+05      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 14           |
# |    iterations           | 21           |
# |    time_elapsed         | 379          |
# |    total_timesteps      | 5376         |
# | train/                  |              |
# |    approx_kl            | 0.0005226594 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 1.79e-07     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 3.1e+04      |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00157     |
# |    value_loss           | 6.07e+04     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 14            |
# |    iterations           | 22            |
# |    time_elapsed         | 397           |
# |    total_timesteps      | 5632          |
# | train/                  |               |
# |    approx_kl            | 0.00051974365 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.09         |
# |    explained_variance   | 2.38e-07      |
# |    learning_rate        | 0.0001        |
# |    loss                 | 9.92e+04      |
# |    n_updates            | 210           |
# |    policy_gradient_loss | -0.00244      |
# |    value_loss           | 2.15e+05      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 14            |
# |    iterations           | 23            |
# |    time_elapsed         | 416           |
# |    total_timesteps      | 5888          |
# | train/                  |               |
# |    approx_kl            | 0.00019603828 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.09         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0001        |
# |    loss                 | 4.91e+04      |
# |    n_updates            | 220           |
# |    policy_gradient_loss | -0.000678     |
# |    value_loss           | 9.73e+04      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 14            |
# |    iterations           | 24            |
# |    time_elapsed         | 435           |
# |    total_timesteps      | 6144          |
# | train/                  |               |
# |    approx_kl            | 0.00022364478 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.09         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.85e+05      |
# |    n_updates            | 230           |
# |    policy_gradient_loss | -0.000954     |
# |    value_loss           | 2.84e+05      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 14           |
# |    iterations           | 25           |
# |    time_elapsed         | 453          |
# |    total_timesteps      | 6400         |
# | train/                  |              |
# |    approx_kl            | 4.741596e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | -2.38e-07    |
# |    learning_rate        | 0.0001       |
# |    loss                 | 5.72e+04     |
# |    n_updates            | 240          |
# |    policy_gradient_loss | 0.000102     |
# |    value_loss           | 1.16e+05     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 14            |
# |    iterations           | 26            |
# |    time_elapsed         | 472           |
# |    total_timesteps      | 6656          |
# | train/                  |               |
# |    approx_kl            | 0.00020638341 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.09         |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0001        |
# |    loss                 | 2.42e+04      |
# |    n_updates            | 250           |
# |    policy_gradient_loss | -0.000558     |
# |    value_loss           | 5.92e+04      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 14           |
# |    iterations           | 27           |
# |    time_elapsed         | 491          |
# |    total_timesteps      | 6912         |
# | train/                  |              |
# |    approx_kl            | 0.0003791263 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0001       |
# |    loss                 | 2.34e+04     |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.000903    |
# |    value_loss           | 5.02e+04     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 14           |
# |    iterations           | 28           |
# |    time_elapsed         | 510          |
# |    total_timesteps      | 7168         |
# | train/                  |              |
# |    approx_kl            | 4.701782e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 5.64e+04     |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -9.55e-05    |
# |    value_loss           | 9.74e+04     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 14            |
# |    iterations           | 29            |
# |    time_elapsed         | 529           |
# |    total_timesteps      | 7424          |
# | train/                  |               |
# |    approx_kl            | 2.5108457e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.09         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.69e+04      |
# |    n_updates            | 280           |
# |    policy_gradient_loss | 9.45e-07      |
# |    value_loss           | 3.58e+04      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 14            |
# |    iterations           | 30            |
# |    time_elapsed         | 548           |
# |    total_timesteps      | 7680          |
# | train/                  |               |
# |    approx_kl            | 0.00021604169 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.09         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0001        |
# |    loss                 | 3.32e+04      |
# |    n_updates            | 290           |
# |    policy_gradient_loss | -0.000682     |
# |    value_loss           | 7.13e+04      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 13           |
# |    iterations           | 31           |
# |    time_elapsed         | 567          |
# |    total_timesteps      | 7936         |
# | train/                  |              |
# |    approx_kl            | 0.0010270334 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.62e+04     |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00205     |
# |    value_loss           | 3.14e+04     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 13           |
# |    iterations           | 32           |
# |    time_elapsed         | 586          |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0003441691 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.58e+04     |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.000565    |
# |    value_loss           | 2.76e+04     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 13           |
# |    iterations           | 33           |
# |    time_elapsed         | 605          |
# |    total_timesteps      | 8448         |
# | train/                  |              |
# |    approx_kl            | 0.0002288986 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 2.26e+04     |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.000648    |
# |    value_loss           | 4.92e+04     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 8.64e+03      |
# |    ep_rew_mean          | -1.28e+05     |
# | time/                   |               |
# |    fps                  | 13            |
# |    iterations           | 34            |
# |    time_elapsed         | 624           |
# |    total_timesteps      | 8704          |
# | train/                  |               |
# |    approx_kl            | 0.00021956232 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.09         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.94e+04      |
# |    n_updates            | 330           |
# |    policy_gradient_loss | -0.0005       |
# |    value_loss           | 5.11e+04      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.64e+03     |
# |    ep_rew_mean          | -1.28e+05    |
# | time/                   |              |
# |    fps                  | 13           |
# |    iterations           | 35           |
# |    time_elapsed         | 643          |
# |    total_timesteps      | 8960         |
# | train/                  |              |
# |    approx_kl            | 9.590178e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0001       |
# |    loss                 | 2.77e+04     |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.000252    |
# |    value_loss           | 5.05e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.64e+03     |
# |    ep_rew_mean          | -1.28e+05    |
# | time/                   |              |
# |    fps                  | 13           |
# |    iterations           | 36           |
# |    time_elapsed         | 662          |
# |    total_timesteps      | 9216         |
# | train/                  |              |
# |    approx_kl            | 0.0022924754 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0001       |
# |    loss                 | 2.56e+04     |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00587     |
# |    value_loss           | 5.23e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.64e+03     |
# |    ep_rew_mean          | -1.28e+05    |
# | time/                   |              |
# |    fps                  | 13           |
# |    iterations           | 37           |
# |    time_elapsed         | 680          |
# |    total_timesteps      | 9472         |
# | train/                  |              |
# |    approx_kl            | 0.0002357841 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.1e+05      |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.000778    |
# |    value_loss           | 1.99e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.64e+03     |
# |    ep_rew_mean          | -1.28e+05    |
# | time/                   |              |
# |    fps                  | 13           |
# |    iterations           | 38           |
# |    time_elapsed         | 699          |
# |    total_timesteps      | 9728         |
# | train/                  |              |
# |    approx_kl            | 0.0004180672 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0001       |
# |    loss                 | 5.56e+04     |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00154     |
# |    value_loss           | 9.8e+04      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 8.64e+03      |
# |    ep_rew_mean          | -1.28e+05     |
# | time/                   |               |
# |    fps                  | 13            |
# |    iterations           | 39            |
# |    time_elapsed         | 718           |
# |    total_timesteps      | 9984          |
# | train/                  |               |
# |    approx_kl            | 4.3502077e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.07         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.46e+05      |
# |    n_updates            | 380           |
# |    policy_gradient_loss | 0.000102      |
# |    value_loss           | 2.42e+05      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 8.64e+03      |
# |    ep_rew_mean          | -1.28e+05     |
# | time/                   |               |
# |    fps                  | 13            |
# |    iterations           | 40            |
# |    time_elapsed         | 737           |
# |    total_timesteps      | 10240         |
# | train/                  |               |
# |    approx_kl            | 0.00015932322 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.07         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0001        |
# |    loss                 | 4.94e+04      |
# |    n_updates            | 390           |
# |    policy_gradient_loss | -0.000694     |
# |    value_loss           | 9.24e+04      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 8.64e+03      |
# |    ep_rew_mean          | -1.28e+05     |
# | time/                   |               |
# |    fps                  | 13            |
# |    iterations           | 41            |
# |    time_elapsed         | 756           |
# |    total_timesteps      | 10496         |
# | train/                  |               |
# |    approx_kl            | 0.00068698917 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.07         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0001        |
# |    loss                 | 2.33e+04      |
# |    n_updates            | 400           |
# |    policy_gradient_loss | -0.00198      |
# |    value_loss           | 4.61e+04      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 8.64e+03      |
# |    ep_rew_mean          | -1.28e+05     |
# | time/                   |               |
# |    fps                  | 13            |
# |    iterations           | 42            |
# |    time_elapsed         | 775           |
# |    total_timesteps      | 10752         |
# | train/                  |               |
# |    approx_kl            | 0.00015376322 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.06         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0001        |
# |    loss                 | 5.34e+04      |
# |    n_updates            | 410           |
# |    policy_gradient_loss | -0.00029      |
# |    value_loss           | 1.12e+05      |
# -------------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 8.64e+03       |
# |    ep_rew_mean          | -1.28e+05      |
# | time/                   |                |
# |    fps                  | 13             |
# |    iterations           | 43             |
# |    time_elapsed         | 793            |
# |    total_timesteps      | 11008          |
# | train/                  |                |
# |    approx_kl            | 0.000118044205 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -1.06          |
# |    explained_variance   | 1.19e-07       |
# |    learning_rate        | 0.0001         |
# |    loss                 | 4.5e+04        |
# |    n_updates            | 420            |
# |    policy_gradient_loss | -0.000395      |
# |    value_loss           | 8.77e+04       |
# --------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 8.64e+03      |
# |    ep_rew_mean          | -1.28e+05     |
# | time/                   |               |
# |    fps                  | 13            |
# |    iterations           | 44            |
# |    time_elapsed         | 812           |
# |    total_timesteps      | 11264         |
# | train/                  |               |
# |    approx_kl            | 0.00019395398 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.05         |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0001        |
# |    loss                 | 6.04e+04      |
# |    n_updates            | 430           |
# |    policy_gradient_loss | -0.000675     |
# |    value_loss           | 1.16e+05      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 8.64e+03      |
# |    ep_rew_mean          | -1.28e+05     |
# | time/                   |               |
# |    fps                  | 13            |
# |    iterations           | 45            |
# |    time_elapsed         | 831           |
# |    total_timesteps      | 11520         |
# | train/                  |               |
# |    approx_kl            | 6.8228226e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.05         |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0001        |
# |    loss                 | 6.51e+04      |
# |    n_updates            | 440           |
# |    policy_gradient_loss | -0.000184     |
# |    value_loss           | 1.23e+05      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.64e+03     |
# |    ep_rew_mean          | -1.28e+05    |
# | time/                   |              |
# |    fps                  | 13           |
# |    iterations           | 46           |
# |    time_elapsed         | 850          |
# |    total_timesteps      | 11776        |
# | train/                  |              |
# |    approx_kl            | 0.0013536329 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0001       |
# |    loss                 | 2.32e+04     |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.00273     |
# |    value_loss           | 4.48e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.64e+03     |
# |    ep_rew_mean          | -1.28e+05    |
# | time/                   |              |
# |    fps                  | 13           |
# |    iterations           | 47           |
# |    time_elapsed         | 868          |
# |    total_timesteps      | 12032        |
# | train/                  |              |
# |    approx_kl            | 0.0032895464 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 3.44e+04     |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00596     |
# |    value_loss           | 7.09e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.64e+03     |
# |    ep_rew_mean          | -1.28e+05    |
# | time/                   |              |
# |    fps                  | 13           |
# |    iterations           | 48           |
# |    time_elapsed         | 887          |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0001001833 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0001       |
# |    loss                 | 3.38e+05     |
# |    n_updates            | 470          |
# |    policy_gradient_loss | 0.000539     |
# |    value_loss           | 4.92e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.64e+03     |
# |    ep_rew_mean          | -1.28e+05    |
# | time/                   |              |
# |    fps                  | 13           |
# |    iterations           | 49           |
# |    time_elapsed         | 906          |
# |    total_timesteps      | 12544        |
# | train/                  |              |
# |    approx_kl            | 2.447283e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0001       |
# |    loss                 | 3.33e+05     |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -1.02e-05    |
# |    value_loss           | 8.27e+05     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 8.64e+03      |
# |    ep_rew_mean          | -1.28e+05     |
# | time/                   |               |
# |    fps                  | 13            |
# |    iterations           | 50            |
# |    time_elapsed         | 925           |
# |    total_timesteps      | 12800         |
# | train/                  |               |
# |    approx_kl            | 5.2900054e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.03         |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0001        |
# |    loss                 | 2.77e+05      |
# |    n_updates            | 490           |
# |    policy_gradient_loss | -0.000655     |
# |    value_loss           | 7.19e+05      |
# -------------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 8.64e+03       |
# |    ep_rew_mean          | -1.28e+05      |
# | time/                   |                |
# |    fps                  | 13             |
# |    iterations           | 51             |
# |    time_elapsed         | 944            |
# |    total_timesteps      | 13056          |
# | train/                  |                |
# |    approx_kl            | 0.000107090455 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -1.03          |
# |    explained_variance   | 1.19e-07       |
# |    learning_rate        | 0.0001         |
# |    loss                 | 1.83e+05       |
# |    n_updates            | 500            |
# |    policy_gradient_loss | -0.000475      |
# |    value_loss           | 4.04e+05       |
# --------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.64e+03     |
# |    ep_rew_mean          | -1.28e+05    |
# | time/                   |              |
# |    fps                  | 13           |
# |    iterations           | 52           |
# |    time_elapsed         | 963          |
# |    total_timesteps      | 13312        |
# | train/                  |              |
# |    approx_kl            | 0.0003155379 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 9.47e+04     |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.00135     |
# |    value_loss           | 1.8e+05      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.64e+03    |
# |    ep_rew_mean          | -1.28e+05   |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 53          |
# |    time_elapsed         | 982         |
# |    total_timesteps      | 13568       |
# | train/                  |             |
# |    approx_kl            | 0.000263019 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.02e+05    |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.00097    |
# |    value_loss           | 1.64e+05    |
# -----------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 8.64e+03       |
# |    ep_rew_mean          | -1.28e+05      |
# | time/                   |                |
# |    fps                  | 13             |
# |    iterations           | 54             |
# |    time_elapsed         | 1000           |
# |    total_timesteps      | 13824          |
# | train/                  |                |
# |    approx_kl            | 0.000113746384 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -1.03          |
# |    explained_variance   | 0              |
# |    learning_rate        | 0.0001         |
# |    loss                 | 1.95e+05       |
# |    n_updates            | 530            |
# |    policy_gradient_loss | -0.000448      |
# |    value_loss           | 5.62e+05       |
# --------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.64e+03     |
# |    ep_rew_mean          | -1.28e+05    |
# | time/                   |              |
# |    fps                  | 13           |
# |    iterations           | 55           |
# |    time_elapsed         | 1019         |
# |    total_timesteps      | 14080        |
# | train/                  |              |
# |    approx_kl            | 3.424869e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0001       |
# |    loss                 | 5.04e+04     |
# |    n_updates            | 540          |
# |    policy_gradient_loss | -8.14e-05    |
# |    value_loss           | 1.17e+05     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 8.64e+03      |
# |    ep_rew_mean          | -1.28e+05     |
# | time/                   |               |
# |    fps                  | 13            |
# |    iterations           | 56            |
# |    time_elapsed         | 1038          |
# |    total_timesteps      | 14336         |
# | train/                  |               |
# |    approx_kl            | 0.00096558593 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.04         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0001        |
# |    loss                 | 3.15e+04      |
# |    n_updates            | 550           |
# |    policy_gradient_loss | -0.00208      |
# |    value_loss           | 6.51e+04      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.64e+03     |
# |    ep_rew_mean          | -1.28e+05    |
# | time/                   |              |
# |    fps                  | 13           |
# |    iterations           | 57           |
# |    time_elapsed         | 1057         |
# |    total_timesteps      | 14592        |
# | train/                  |              |
# |    approx_kl            | 0.0002561172 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | -2.38e-07    |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.02e+05     |
# |    n_updates            | 560          |
# |    policy_gradient_loss | -0.000687    |
# |    value_loss           | 2.1e+05      |
# ...
# |    n_updates            | 4300          |
# |    policy_gradient_loss | -0.00033      |
# |    value_loss           | 1.49e+04      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.64e+03     |
# |    ep_rew_mean          | -1.57e+05    |
# | time/                   |              |
# |    fps                  | 13           |
# |    iterations           | 41           |
# |    time_elapsed         | 764          |
# |    total_timesteps      | 110592       |
# | train/                  |              |
# |    approx_kl            | 3.268686e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.997       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0001       |
# |    loss                 | 3.23e+04     |
# |    n_updates            | 4310         |
# |    policy_gradient_loss | -8.41e-05    |
# |    value_loss           | 6.8e+04      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 8.64e+03      |
# |    ep_rew_mean          | -1.57e+05     |
# | time/                   |               |
# |    fps                  | 13            |
# |    iterations           | 42            |
# |    time_elapsed         | 784           |
# |    total_timesteps      | 110848        |
# | train/                  |               |
# |    approx_kl            | 0.00048329914 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.993        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.48e+04      |
# |    n_updates            | 4320          |
# |    policy_gradient_loss | -0.00112      |
# |    value_loss           | 2.75e+04      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 8.64e+03      |
# |    ep_rew_mean          | -1.57e+05     |
# | time/                   |               |
# |    fps                  | 13            |
# |    iterations           | 43            |
# |    time_elapsed         | 803           |
# |    total_timesteps      | 111104        |
# | train/                  |               |
# |    approx_kl            | 0.00015614368 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.983        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0001        |
# |    loss                 | 7.68e+03      |
# |    n_updates            | 4330          |
# |    policy_gradient_loss | -0.000156     |
# |    value_loss           | 1.62e+04      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 8.64e+03      |
# |    ep_rew_mean          | -1.57e+05     |
# | time/                   |               |
# |    fps                  | 13            |
# |    iterations           | 44            |
# |    time_elapsed         | 822           |
# |    total_timesteps      | 111360        |
# | train/                  |               |
# |    approx_kl            | 4.5693014e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.982        |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0001        |
# |    loss                 | 6.89e+03      |
# |    n_updates            | 4340          |
# |    policy_gradient_loss | 1.86e-05      |
# |    value_loss           | 1.79e+04      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.64e+03     |
# |    ep_rew_mean          | -1.57e+05    |
# | time/                   |              |
# |    fps                  | 13           |
# |    iterations           | 45           |
# |    time_elapsed         | 842          |
# |    total_timesteps      | 111616       |
# | train/                  |              |
# |    approx_kl            | 9.109965e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.981       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0001       |
# |    loss                 | 2.56e+04     |
# |    n_updates            | 4350         |
# |    policy_gradient_loss | -1.98e-05    |
# |    value_loss           | 3.96e+04     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 8.64e+03      |
# |    ep_rew_mean          | -1.57e+05     |
# | time/                   |               |
# |    fps                  | 13            |
# |    iterations           | 46            |
# |    time_elapsed         | 862           |
# |    total_timesteps      | 111872        |
# | train/                  |               |
# |    approx_kl            | 2.5010668e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.98         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.89e+04      |
# |    n_updates            | 4360          |
# |    policy_gradient_loss | 1.3e-05       |
# |    value_loss           | 4.65e+04      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.64e+03     |
# |    ep_rew_mean          | -1.57e+05    |
# | time/                   |              |
# |    fps                  | 13           |
# |    iterations           | 47           |
# |    time_elapsed         | 881          |
# |    total_timesteps      | 112128       |
# | train/                  |              |
# |    approx_kl            | 0.0005156854 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.98        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0001       |
# |    loss                 | 4.61e+04     |
# |    n_updates            | 4370         |
# |    policy_gradient_loss | -0.00255     |
# |    value_loss           | 8.4e+04      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.64e+03     |
# |    ep_rew_mean          | -1.57e+05    |
# | time/                   |              |
# |    fps                  | 13           |
# |    iterations           | 48           |
# |    time_elapsed         | 901          |
# |    total_timesteps      | 112384       |
# | train/                  |              |
# |    approx_kl            | 0.0028449616 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.968       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0001       |
# |    loss                 | 7.52e+03     |
# |    n_updates            | 4380         |
# |    policy_gradient_loss | -0.00453     |
# |    value_loss           | 1.51e+04     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 8.64e+03      |
# |    ep_rew_mean          | -1.57e+05     |
# | time/                   |               |
# |    fps                  | 13            |
# |    iterations           | 49            |
# |    time_elapsed         | 921           |
# |    total_timesteps      | 112640        |
# | train/                  |               |
# |    approx_kl            | 2.5208341e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.95         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0001        |
# |    loss                 | 2.21e+04      |
# |    n_updates            | 4390          |
# |    policy_gradient_loss | 0.000292      |
# |    value_loss           | 3.96e+04      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 8.64e+03      |
# |    ep_rew_mean          | -1.57e+05     |
# | time/                   |               |
# |    fps                  | 13            |
# |    iterations           | 50            |
# |    time_elapsed         | 940           |
# |    total_timesteps      | 112896        |
# | train/                  |               |
# |    approx_kl            | 1.9847648e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.957        |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.26e+05      |
# |    n_updates            | 4400          |
# |    policy_gradient_loss | 4.69e-05      |
# |    value_loss           | 2.75e+05      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 8.64e+03      |
# |    ep_rew_mean          | -1.57e+05     |
# | time/                   |               |
# |    fps                  | 13            |
# |    iterations           | 51            |
# |    time_elapsed         | 960           |
# |    total_timesteps      | 113152        |
# | train/                  |               |
# |    approx_kl            | 0.00028447877 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.963        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0001        |
# |    loss                 | 4.79e+04      |
# |    n_updates            | 4410          |
# |    policy_gradient_loss | -0.00134      |
# |    value_loss           | 9.35e+04      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 8.64e+03      |
# |    ep_rew_mean          | -1.57e+05     |
# | time/                   |               |
# |    fps                  | 13            |
# |    iterations           | 52            |
# |    time_elapsed         | 979           |
# |    total_timesteps      | 113408        |
# | train/                  |               |
# |    approx_kl            | 0.00012028846 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.971        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0001        |
# |    loss                 | 3.07e+04      |
# |    n_updates            | 4420          |
# |    policy_gradient_loss | -0.000498     |
# |    value_loss           | 5.77e+04      |
# -------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 86
#      83 for i in range(chunks):
#      84     print(f"\n[🔁 TRAINING CHUNK {i+1}/{chunks}]")
# ---> 86     model.learn(total_timesteps=chunk_size, reset_num_timesteps=False)
#      88     steps_so_far = (i+1) * chunk_size
#      89     chunk_model_path = f"{base_model_path}-{steps_so_far//1000}k"
#
# File ~/MSDS Research/StockMarketComputerVisionResearch/.venv/lib/python3.12/site-packages/stable_baselines3/ppo/ppo.py:311, in PPO.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     302 def learn(
#     303     self: SelfPPO,
#     304     total_timesteps: int,
#    (...)    309     progress_bar: bool = False,
#     310 ) -> SelfPPO:
# --> 311     return super().learn(
#     312         total_timesteps=total_timesteps,
#     313         callback=callback,
#     314         log_interval=log_interval,
#     315         tb_log_name=tb_log_name,
#     316         reset_num_timesteps=reset_num_timesteps,
#     317         progress_bar=progress_bar,
#     318     )
#
# File ~/MSDS Research/StockMarketComputerVisionResearch/.venv/lib/python3.12/site-packages/stable_baselines3/common/on_policy_algorithm.py:337, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     334         assert self.ep_info_buffer is not None
#     335         self.dump_logs(iteration)
# --> 337     self.train()
#     339 callback.on_training_end()
#     341 return self
#
# File ~/MSDS Research/StockMarketComputerVisionResearch/.venv/lib/python3.12/site-packages/stable_baselines3/ppo/ppo.py:213, in PPO.train(self)
#     209 if isinstance(self.action_space, spaces.Discrete):
#     210     # Convert discrete action from float to long
#     211     actions = rollout_data.actions.long().flatten()
# --> 213 values, log_prob, entropy = self.policy.evaluate_actions(rollout_data.observations, actions)
#     214 values = values.flatten()
#     215 # Normalize advantage
#
# File ~/MSDS Research/StockMarketComputerVisionResearch/.venv/lib/python3.12/site-packages/stable_baselines3/common/policies.py:737, in ActorCriticPolicy.evaluate_actions(self, obs, actions)
#     735     latent_pi = self.mlp_extractor.forward_actor(pi_features)
#     736     latent_vf = self.mlp_extractor.forward_critic(vf_features)
# --> 737 distribution = self._get_action_dist_from_latent(latent_pi)
#     738 log_prob = distribution.log_prob(actions)
#     739 values = self.value_net(latent_vf)
#
# File ~/MSDS Research/StockMarketComputerVisionResearch/.venv/lib/python3.12/site-packages/stable_baselines3/common/policies.py:697, in ActorCriticPolicy._get_action_dist_from_latent(self, latent_pi)
#     694     return self.action_dist.proba_distribution(mean_actions, self.log_std)
#     695 elif isinstance(self.action_dist, CategoricalDistribution):
#     696     # Here mean_actions are the logits before the softmax
# --> 697     return self.action_dist.proba_distribution(action_logits=mean_actions)
#     698 elif isinstance(self.action_dist, MultiCategoricalDistribution):
#     699     # Here mean_actions are the flattened logits
#     700     return self.action_dist.proba_distribution(action_logits=mean_actions)
#
# File ~/MSDS Research/StockMarketComputerVisionResearch/.venv/lib/python3.12/site-packages/stable_baselines3/common/distributions.py:288, in CategoricalDistribution.proba_distribution(self, action_logits)
#     287 def proba_distribution(self: SelfCategoricalDistribution, action_logits: th.Tensor) -> SelfCategoricalDistribution:
# --> 288     self.distribution = Categorical(logits=action_logits)
#     289     return self
#
# File ~/MSDS Research/StockMarketComputerVisionResearch/.venv/lib/python3.12/site-packages/torch/distributions/categorical.py:81, in Categorical.__init__(self, probs, logits, validate_args)
#      77 self._num_events = self._param.size()[-1]
#      78 batch_shape = (
#      79     self._param.size()[:-1] if self._param.ndimension() > 1 else torch.Size()
#      80 )
# ---> 81 super().__init__(batch_shape, validate_args=validate_args)
#
# File ~/MSDS Research/StockMarketComputerVisionResearch/.venv/lib/python3.12/site-packages/torch/distributions/distribution.py:76, in Distribution.__init__(self, batch_shape, event_shape, validate_args)
#      74         value = getattr(self, param)
#      75         valid = constraint.check(value)
# ---> 76         if not torch._is_all_true(valid):
#      77             raise ValueError(
#      78                 f"Expected parameter {param} "
#      79                 f"({type(value).__name__} of shape {tuple(value.shape)}) "
#    (...)     82                 f"but found invalid values:\n{value}"
#      83             )
#      84 super().__init__()
#
# KeyboardInterrupt:
