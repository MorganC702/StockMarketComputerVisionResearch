# %%
import os
import glob
import ultralytics
from ultralytics import YOLO

model = YOLO('yolov8n.pt')
model.to('cuda')
# Out:
# YOLO(
#   (model): DetectionModel(
#     (model): Sequential(
#       (0): Conv(
#         (conv): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (1): Conv(
#         (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (2): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(48, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (3): Conv(
#         (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (4): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0-1): 2 x Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (5): Conv(
#         (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (6): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0-1): 2 x Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (7): Conv(
#         (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (8): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(384, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (9): SPPF(
#         (cv1): Conv(
#           (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): MaxPool2d(kernel_size=5, stride=1, padding=2, dilation=1, ceil_mode=False)
#       )
#       (10): Upsample(scale_factor=2.0, mode='nearest')
#       (11): Concat()
#       (12): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (13): Upsample(scale_factor=2.0, mode='nearest')
#       (14): Concat()
#       (15): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(96, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (16): Conv(
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (17): Concat()
#       (18): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (19): Conv(
#         (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (20): Concat()
#       (21): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(384, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(384, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (22): Detect(
#         (cv2): ModuleList(
#           (0): Sequential(
#             (0): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (1): Sequential(
#             (0): Conv(
#               (conv): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (2): Sequential(
#             (0): Conv(
#               (conv): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#         (cv3): ModuleList(
#           (0): Sequential(
#             (0): Conv(
#               (conv): Conv2d(64, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (2): Conv2d(80, 80, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (1): Sequential(
#             (0): Conv(
#               (conv): Conv2d(128, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (2): Conv2d(80, 80, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (2): Sequential(
#             (0): Conv(
#               (conv): Conv2d(256, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (2): Conv2d(80, 80, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#         (dfl): DFL(
#           (conv): Conv2d(16, 1, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#       )
#     )
#   )
# )

# %%
for f in glob.glob("../**/*.cache", recursive=True):
    os.remove(f)

model.train(
    data='../dataset/data.yaml',
    epochs=100,
    # lr0=0.0003,
    imgsz=640,
    batch=16,
    patience=10,
    project='runs',
    name='yolo_run_',
    device=0,
    verbose=True,
    workers=2,  # keep this small if RAM is tight
    cache=False, # prevents loading the entire dataset into RAM

    # Turn off augmentations for now since its simple charts and idk sh about f.
    # we can add them back as we know wht they do and interate. 
    mosaic=0.0,
    mixup=0.0,
    copy_paste=0.0,
    hsv_h=0.0,
    hsv_s=0.0,
    hsv_v=0.0,
    shear=0.0,
    perspective=0.0,
    flipud=0.0,
    fliplr=0.0,
    erasing=0.0,

    # Acceptable augmentations for stock data
    translate=0.0,
    scale=0.0
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.204 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.200 🚀 Python-3.12.3 torch-2.8.0+cu128 CUDA:0 (NVIDIA GeForce RTX 4080, 16064MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=../dataset/data.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.0, exist_ok=False, fliplr=0.0, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.0, hsv_s=0.0, hsv_v=0.0, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n.pt, momentum=0.937, mosaic=0.0, multi_scale=False, name=yolo_run_2, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=10, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=runs, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/models/runs/yolo_run_2, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.0, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.0, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=2, workspace=None
# Overriding model.yaml nc=80 with nc=3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    751897  ultralytics.nn.modules.head.Detect           [3, [64, 128, 256]]
# Model summary: 129 layers, 3,011,433 parameters, 3,011,417 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2613.9±1203.0 MB/s, size: 31.6 KB)
# train: Scanning /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/labels/15m... 7835 images, 1 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 7836/7836 6.3Kit/s 1.2s0.0s
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 16:00:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 16:01:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 16:02:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 16:03:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 16:04:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 16:05:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 16:06:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 16:07:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 16:08:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 16:09:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 16:10:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 16:11:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 16:12:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 16:13:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 16:14:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 16:15:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 16:16:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 16:17:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 16:18:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 16:19:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 16:20:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 16:21:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 16:22:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 16:23:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 16:24:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 16:25:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 16:26:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 16:27:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 16:28:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 16:29:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 16:30:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 16:31:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 16:32:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 16:33:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 16:34:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 16:35:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 16:36:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 16:37:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 16:38:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 16:39:00.png: 2 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 16:40:00.png: 2 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 16:41:00.png: 2 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 16:42:00.png: 2 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 16:43:00.png: 2 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 16:44:00.png: 2 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 16:45:00.png: 2 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 16:46:00.png: 2 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 16:47:00.png: 2 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 16:48:00.png: 2 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 16:49:00.png: 2 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 16:50:00.png: 2 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 16:51:00.png: 2 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 16:52:00.png: 2 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 16:53:00.png: 2 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 16:54:00.png: 2 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 16:55:00.png: 2 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 16:56:00.png: 2 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 16:57:00.png: 2 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 16:58:00.png: 2 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 16:59:00.png: 2 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 17:00:00.png: 2 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 17:01:00.png: 2 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 17:02:00.png: 2 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 17:03:00.png: 2 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 17:04:00.png: 2 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 17:05:00.png: 2 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 17:06:00.png: 2 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 17:07:00.png: 2 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 17:08:00.png: 2 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 17:09:00.png: 2 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 17:10:00.png: 2 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 17:11:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 17:12:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 17:13:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 17:14:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 17:15:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 17:16:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 17:17:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 17:18:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 17:19:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 17:20:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 17:21:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 17:22:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 17:23:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 17:24:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 17:25:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 17:26:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 17:27:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 17:28:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 17:29:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 17:30:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 17:31:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 17:32:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 17:33:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 17:36:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 17:37:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 17:38:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 17:39:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 17:40:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 17:41:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 17:42:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 17:43:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 17:44:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 17:45:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 17:46:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 17:47:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 17:48:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 17:49:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 17:51:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 17:52:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 17:53:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 17:54:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 17:55:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 17:56:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 17:57:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 17:58:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 17:59:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 18:00:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 18:02:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 18:03:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 18:04:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 18:05:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 18:06:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 18:07:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 18:08:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 18:09:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 18:10:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 18:11:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 18:12:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 18:13:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 18:14:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 18:15:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 18:16:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 18:17:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 18:18:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 18:19:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 18:20:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 18:21:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 18:22:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 18:23:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 18:24:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 18:25:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 18:26:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 18:27:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 18:28:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 18:29:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 18:30:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 18:31:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 18:32:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 18:33:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 18:34:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 18:35:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 18:36:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 18:37:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 18:38:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 18:39:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 18:40:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 18:41:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 18:42:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 18:43:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 18:44:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 18:45:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 18:46:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 18:47:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 18:48:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 18:49:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 18:50:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 18:51:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 18:52:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 18:53:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 18:54:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 18:55:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 18:56:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 18:57:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 18:58:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 18:59:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 19:00:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 19:01:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 19:02:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 19:03:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 19:04:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 19:05:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 19:06:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 19:07:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 19:08:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 19:09:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 19:10:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 19:11:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 19:12:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 19:13:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 19:14:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 19:15:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 19:16:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 19:17:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 19:18:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 19:19:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 19:20:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 19:21:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 19:22:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 19:23:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 19:24:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 19:25:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 19:26:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 19:27:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 19:28:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 19:29:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 19:30:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 19:31:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 19:32:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 19:33:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 19:34:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 19:35:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 19:36:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 19:37:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 19:38:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 19:39:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 19:40:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 19:41:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 19:42:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 19:43:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 19:44:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 19:45:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 19:46:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 19:47:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 19:48:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 19:49:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 19:50:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 19:51:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 19:52:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 19:53:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 19:54:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 19:55:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 19:56:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 19:57:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 19:58:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 19:59:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 20:00:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 20:01:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 20:02:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 20:03:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 20:04:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 20:05:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 20:06:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 20:07:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 20:08:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 20:09:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 20:10:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 20:11:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 20:12:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 20:13:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 20:14:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 20:15:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 20:16:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/1m/2024-09-27 20:17:00.png: 1 duplicate labels removed
# ...
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/3m/2024-09-30 07:58:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/3m/2024-09-30 07:59:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/3m/2024-09-30 08:00:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/3m/2024-09-30 08:01:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/3m/2024-09-30 08:02:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/3m/2024-09-30 08:03:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/3m/2024-09-30 08:04:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/3m/2024-09-30 08:05:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/3m/2024-09-30 08:06:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/3m/2024-09-30 08:07:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/3m/2024-09-30 08:08:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/3m/2024-09-30 08:09:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/3m/2024-09-30 08:10:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/3m/2024-09-30 08:11:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/3m/2024-09-30 08:12:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/3m/2024-09-30 08:13:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/3m/2024-09-30 08:14:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/3m/2024-09-30 08:15:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/3m/2024-09-30 08:16:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/3m/2024-09-30 08:17:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/3m/2024-09-30 08:18:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/3m/2024-09-30 08:19:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/3m/2024-09-30 08:20:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/3m/2024-09-30 08:21:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/3m/2024-09-30 08:22:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/3m/2024-09-30 08:23:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/3m/2024-09-30 08:24:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/3m/2024-09-30 08:25:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/3m/2024-09-30 08:26:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/3m/2024-09-30 08:27:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/3m/2024-09-30 08:28:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/3m/2024-09-30 08:29:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/3m/2024-09-30 08:30:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/3m/2024-09-30 08:31:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/3m/2024-09-30 08:32:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/3m/2024-09-30 08:33:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/3m/2024-09-30 08:34:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/3m/2024-09-30 08:35:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/3m/2024-09-30 08:36:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/3m/2024-09-30 08:37:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/3m/2024-09-30 08:38:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/3m/2024-09-30 08:39:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/3m/2024-09-30 08:40:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/3m/2024-09-30 08:41:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/3m/2024-09-30 08:42:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/3m/2024-09-30 08:43:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/3m/2024-09-30 08:44:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/3m/2024-09-30 08:45:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/3m/2024-09-30 08:46:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/3m/2024-09-30 08:47:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/3m/2024-09-30 08:48:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/3m/2024-09-30 08:49:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/3m/2024-09-30 08:50:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/3m/2024-09-30 08:51:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/3m/2024-09-30 08:52:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/3m/2024-09-30 08:53:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/3m/2024-09-30 08:54:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/3m/2024-09-30 08:55:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/3m/2024-09-30 08:56:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/3m/2024-09-30 08:57:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/3m/2024-09-30 08:58:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/3m/2024-09-30 08:59:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/3m/2024-09-30 09:00:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/3m/2024-09-30 09:01:00.png: 1 duplicate labels removed
# train: /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/dataset/images/3m/2024-09-30 09:02:00.png: 1 duplicate labels removed
# Plotting labels to /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/models/runs/yolo_run_2/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: SGD(lr=0.01, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /home/morgan-cooper/MSDS Research/StockMarketComputerVisionResearch/reinforcement_learning/models/runs/yolo_run_2
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      2.05G     0.4943      1.266     0.7948         23        640: 100% ━━━━━━━━━━━╸ 489/490 17.3it/s 22.3s<0.1s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 4
#       1 for f in glob.glob("../**/*.cache", recursive=True):
#       2     os.remove(f)
# ----> 4 model.train(
#       5     data='../dataset/data.yaml',
#       6     epochs=100,
#       7     # lr0=0.0003,
#       8     imgsz=640,
#       9     batch=16,
#      10     patience=10,
#      11     project='runs',
#      12     name='yolo_run_',
#      13     device=0,
#      14     verbose=True,
#      15     workers=2,  # keep this small if RAM is tight
#      16     cache=False, # prevents loading the entire dataset into RAM
#      17
#      18     # Turn off augmentations for now since its simple charts and idk sh about f.
#      19     # we can add them back as we know wht they do and interate.
#      20     mosaic=0.0,
#      21     mixup=0.0,
#      22     copy_paste=0.0,
#      23     hsv_h=0.0,
#      24     hsv_s=0.0,
#      25     hsv_v=0.0,
#      26     shear=0.0,
#      27     perspective=0.0,
#      28     flipud=0.0,
#      29     fliplr=0.0,
#      30     erasing=0.0,
#      31
#      32     # Acceptable augmentations for stock data
#      33     translate=0.0,
#      34     scale=0.0
#      35 )
#
# File ~/MSDS Research/StockMarketComputerVisionResearch/.venv/lib/python3.12/site-packages/ultralytics/engine/model.py:800, in Model.train(self, trainer, **kwargs)
#     797     self.trainer.model = self.trainer.get_model(weights=self.model if self.ckpt else None, cfg=self.model.yaml)
#     798     self.model = self.trainer.model
# --> 800 self.trainer.train()
#     801 # Update model and cfg after training
#     802 if RANK in {-1, 0}:
#
# File ~/MSDS Research/StockMarketComputerVisionResearch/.venv/lib/python3.12/site-packages/ultralytics/engine/trainer.py:235, in BaseTrainer.train(self)
#     232         ddp_cleanup(self, str(file))
#     234 else:
# --> 235     self._do_train()
#
# File ~/MSDS Research/StockMarketComputerVisionResearch/.venv/lib/python3.12/site-packages/ultralytics/engine/trainer.py:429, in BaseTrainer._do_train(self)
#     424     self.tloss = (
#     425         (self.tloss * i + self.loss_items) / (i + 1) if self.tloss is not None else self.loss_items
#     426     )
#     428 # Backward
# --> 429 self.scaler.scale(self.loss).backward()
#     431 # Optimize - https://pytorch.org/docs/master/notes/amp_examples.html
#     432 if ni - last_opt_step >= self.accumulate:
#
# File ~/MSDS Research/StockMarketComputerVisionResearch/.venv/lib/python3.12/site-packages/torch/_tensor.py:647, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     637 if has_torch_function_unary(self):
#     638     return handle_torch_function(
#     639         Tensor.backward,
#     640         (self,),
#    (...)    645         inputs=inputs,
#     646     )
# --> 647 torch.autograd.backward(
#     648     self, gradient, retain_graph, create_graph, inputs=inputs
#     649 )
#
# File ~/MSDS Research/StockMarketComputerVisionResearch/.venv/lib/python3.12/site-packages/torch/autograd/__init__.py:354, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     349     retain_graph = create_graph
#     351 # The reason we repeat the same comment below is that
#     352 # some Python versions print out the first line of a multi-line function
#     353 # calls in the traceback and some print out the last line
# --> 354 _engine_run_backward(
#     355     tensors,
#     356     grad_tensors_,
#     357     retain_graph,
#     358     create_graph,
#     359     inputs_tuple,
#     360     allow_unreachable=True,
#     361     accumulate_grad=True,
#     362 )
#
# File ~/MSDS Research/StockMarketComputerVisionResearch/.venv/lib/python3.12/site-packages/torch/autograd/graph.py:829, in _engine_run_backward(t_outputs, *args, **kwargs)
#     827     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     828 try:
# --> 829     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     830         t_outputs, *args, **kwargs
#     831     )  # Calls into the C++ engine to run the backward pass
#     832 finally:
#     833     if attach_logging_hooks:
#
# KeyboardInterrupt:
